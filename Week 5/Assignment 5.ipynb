# %% [markdown]
# ## Assignment 5
#
#
# IS 362 – Week 5 Assignment
# PAGE 1 OF 1
# Your task in this week’s assignment is to answer three questions:
# 1. What is the northernmost airport in the United States?
# 2. What is the easternmost airport in the United States?
# 3. On February 12 th
# , 2013, which New York area airport had the windiest weather?
# Being successful on this assignment requires using both:
# • Your developing skills in Python and pandas, and
# • Your research skills in validating your candidate answers in context.
#
# Tasks
#
# 1. Use the information in the .CSV files found at
# https://github.com/hadley/nycflights13/tree/master/data-raw for your source data.
# 2. Write your code using Python and pandas, and deliver it in a Jupyter notebook. You should post
# your notebook in a GitHub repository, and send me a link to the notebook.
# 3. For each of the three questions listed above, you’ll need to verify your answers (in two cases by
# searching for additional confirming information, and in the third case being alert for possible
# outliers). For the first two questions above, you may want to start by generating a list of the five
# northernmost or easternmost U.S. airports.
# 4. In addition to providing code, you should state your answers to each of the above questions (in
# Markdown) in the Jupyter notebook.
# 5. To receive full credit, you’ll need to include in your Jupyter notebook both your code and your
# documented assumptions and any changes that you made to the data based on your research
# (using Markdown) in your Jupyter notebook
#
# ![image.png](attachment:image.png)

# %%
import pandas as pd

# %% [raw]
# I will now use pandas to read the airports.csv file

# %% [markdown]
# Question #1 is What is the northernmost airport in the United States? To answer this question, I will sort airports by latitude in descending order. I will then choose the airport with the highest latitude where the tzone is America

# %%
airports = pd.read_csv("https://raw.githubusercontent.com/hadley/nycflights13/master/data-raw/airports.csv")

# %% [markdown]
# To display the types of data in the file, I will just show the first five entries

# %%
airports.head()
# Out:
#    faa                           name        lat        lon   alt  tz dst  \
# 0  04G              Lansdowne Airport  41.130472 -80.619583  1044  -5   A
# 1  06A  Moton Field Municipal Airport  32.460572 -85.680028   264  -6   A
# 2  06C            Schaumburg Regional  41.989341 -88.101243   801  -6   A
# 3  06N                Randall Airport  41.431912 -74.391561   523  -5   A
# 4  09J          Jekyll Island Airport  31.074472 -81.427778    11  -5   A
#
#               tzone
# 0  America/New_York
# 1   America/Chicago
# 2   America/Chicago
# 3  America/New_York
# 4  America/New_York

# %% [markdown]
# I will now sort the airports by latitude in descending order to show the airports with the highest latitude.

# %%
airports.sort_values("lat", ascending = False).head()
# Out:
#      faa                                        name        lat         lon  \
# 417  EEN                     Dillant Hopkins Airport  72.270833   42.898333
# 230  BRW                  Wiley Post Will Rogers Mem  71.285446 -156.766003
# 110  AIN                          Wainwright Airport  70.638056 -159.994722
# 708  K03                               Wainwright As  70.613378 -159.860350
# 152  ATK  Atqasuk Edward Burnell Sr Memorial Airport  70.467300 -157.436000
#
#      alt  tz dst              tzone
# 417  149  -5   A                NaN
# 230   44  -9   A  America/Anchorage
# 110   41  -9   A  America/Anchorage
# 708   35  -9   A  America/Anchorage
# 152   96  -9   A  America/Anchorage

# %% [markdown]
# At first glance, it looks like Dillant Hopkins Airport is the nothernmost. However, the longitude is positive, indicating that the location is in the Eastern Hemisphere. Having googled Dillant Hopkins Airport, it looks like the longitude listed should have been the latitude, and the latitude listed should've been negative  of the latitude listed. ![EEN.jpg](attachment:EEN.jpg) Therefore, the answer to the question is __Wiley Post Will Rogers Mem Airport__. This makes sense since you wouold expect the northernmost airport in the United States to be in Alaska.

# %% [markdown]
# Question #2 is What is the easternmost airport in the United States? To answer this question, I will sort airports by longitude in descending order. I will then choose the airport with the highest longitude where the tzone is America.

# %%
airports.sort_values("lon", ascending = False).head()
# Out:
#       faa                           name        lat         lon   alt  tz dst  \
# 1290  SYA                   Eareckson As  52.712275  174.113620    98  -9   A
# 942   MYF               Montgomery Field  32.475900  117.759000    17   8   A
# 396   DVT  Deer Valley Municipal Airport  33.411700  112.457000  1478   8   A
# 417   EEN        Dillant Hopkins Airport  72.270833   42.898333   149  -5   A
# 444   EPM     Eastport Municipal Airport  44.910111  -67.012694    45  -5   A
#
#                   tzone
# 1290  America/Anchorage
# 942      Asia/Chongqing
# 396      Asia/Chongqing
# 417                 NaN
# 444    America/New_York

# %% [markdown]
# For the airport to be in the Western Hemisphere, the longitude should be negative. The farther you go east in the Western Hemisphere, the less negative the longitude will be. SYA airport is in the U.S. but this airport is actually considered to be in the Eastern Hemisphere. I found the following explanation from Google: ![Alaska.jpg](attachment:Alaska.jpg). The next two airports are not in America. The 4th airport listed we've seen from our sort and know that the data is incorrect. Therefore, the answer to this question is __Eastport Municipal Airport__. This make sense since this airport is in the most eastern part of Maine. I confirmed this with a Google search.![EPM.jpg](attachment:EPM.jpg)

# %% [markdown]
# Question #3 asks on February 12 th , 2013, which New York area airport had the windiest weather? Being successful on this assignment requires using both: • Your developing skills in Python and pandas, and • Your research skills in validating your candidate answers in context.

# %% [markdown]
# I will now use pandas to read the weather.csv file

# %%
weather = pd.read_csv("https://raw.githubusercontent.com/hadley/nycflights13/master/data-raw/weather.csv")

# %% [markdown]
# To display the types of data in the file, I will just show the first five entries

# %%
weather.head()
# Out:
#   origin  year  month  day  hour   temp   dewp  humid  wind_dir  wind_speed  \
# 0    EWR  2013      1    1     1  39.02  26.06  59.37     270.0    10.35702
# 1    EWR  2013      1    1     2  39.02  26.96  61.63     250.0     8.05546
# 2    EWR  2013      1    1     3  39.02  28.04  64.43     240.0    11.50780
# 3    EWR  2013      1    1     4  39.92  28.04  62.21     250.0    12.65858
# 4    EWR  2013      1    1     5  39.02  28.04  64.43     260.0    12.65858
#
#    wind_gust  precip  pressure  visib             time_hour
# 0        NaN     0.0    1012.0   10.0  2013-01-01T06:00:00Z
# 1        NaN     0.0    1012.3   10.0  2013-01-01T07:00:00Z
# 2        NaN     0.0    1012.5   10.0  2013-01-01T08:00:00Z
# 3        NaN     0.0    1012.2   10.0  2013-01-01T09:00:00Z
# 4        NaN     0.0    1011.9   10.0  2013-01-01T10:00:00Z

# %% [markdown]
# Having only seen the first few entries, I need to find out which airports are included, so I can focus on the New York area airports

# %%
weather.origin.unique()
# Out:
# array(['EWR', 'JFK', 'LGA'], dtype=object)

# %% [markdown]
# This result has shown me that the data is consists only of New York area airports.
#
# Next, I only need data for February 12, 2013.

# %%
February_12_2013 = weather[(weather.year == 2013) & (weather.month == 2) & (weather.day == 12)]

# %% [markdown]
# Next I will sort this data by wind speed, from highest to lowest.

# %%
February_12_2013.sort_values(by = "wind_speed", ascending = False).head()
# Out:
#       origin  year  month  day  hour   temp   dewp  humid  wind_dir  \
# 1009     EWR  2013      2   12     3  39.02  26.96  61.63     260.0
# 18417    LGA  2013      2   12     2  42.98  26.06  50.94     290.0
# 1018     EWR  2013      2   12    12  44.06  26.06  48.87     270.0
# 18428    LGA  2013      2   12    13  44.06  23.00  43.02     300.0
# 18429    LGA  2013      2   12    14  44.06  23.00  43.02     300.0
#
#        wind_speed  wind_gust  precip  pressure  visib             time_hour
# 1009   1048.36058        NaN     0.0    1008.3   10.0  2013-02-12T08:00:00Z
# 18417    23.01560   31.07106     0.0    1007.1   10.0  2013-02-12T07:00:00Z
# 1018     21.86482   31.07106     0.0    1012.5   10.0  2013-02-12T17:00:00Z
# 18428    21.86482   25.31716     0.0    1011.7   10.0  2013-02-12T18:00:00Z
# 18429    20.71404   25.31716     0.0    1011.5   10.0  2013-02-12T19:00:00Z

# %% [markdown]
# At first glance, it looks like Newark Airport had the highest wind speed.  Roughly 1,048 mph is impossible. In fact, I googled the fastest wind speed ever recorded and it was much less:
# ![wind_speed.jpg](attachment:wind_speed.jpg) Therefore, the answer to this question is __LaGuardia Airport__.
