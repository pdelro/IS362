# %% [markdown]
# ## Assignment 3
#
# Suppose you have ridden a bicycle from New York City to Key West, Florida. Your bicycle odometer shows the total miles, which you have dutifully logged at the end of each day with paper and pencil. Your first two entries might be 55 and 120, indicating that you rode your bike 55 miles on day 1 and 65 miles on day 2. Your task is to create a pandas Series object that holds the cumulative miles at the end of each day, then use your Python skills to show the total miles that you rode each day. Consider how you should best present this information in a Jupyter notebook. You should save your Jupyter Notebook to your GitHub repository, and provide a link in your assignment submission.
#
# ![NYC_Key%20West.jpg](attachment:NYC_Key%20West.jpg)
#
# I will estimate that I will alternate between riding 55 miles and 65 miles a day except for the last day.

# %%
import pandas as pd
from pprint import pprint

# %%
odometer = {}
odometer['Day 1'] = 55
odometer['Day 2'] = 120
odometer['Day 3'] = 175
odometer['Day 4'] = 240
odometer['Day 5'] = 295
odometer['Day 6'] = 360
odometer['Day 7'] = 415
odometer['Day 8'] = 480
odometer['Day 9'] = 535
odometer['Day 10'] = 600
odometer['Day 11'] = 655
odometer['Day 12'] = 720
odometer['Day 13'] = 775
odometer['Day 14'] = 840
odometer['Day 15'] = 905
odometer['Day 16'] = 960
odometer['Day 17'] = 1025
odometer['Day 18'] = 1080
odometer['Day 19'] = 1145
odometer['Day 20'] = 1200
odometer['Day 21'] = 1265
odometer['Day 22'] = 1320
odometer['Day 23'] = 1385
odometer['Day 24'] = 1440
odometer['Day 25'] = 1514
pprint (odometer)
# Out:
# {'Day 1': 55,
#  'Day 10': 600,
#  'Day 11': 655,
#  'Day 12': 720,
#  'Day 13': 775,
#  'Day 14': 840,
#  'Day 15': 905,
#  'Day 16': 960,
#  'Day 17': 1025,
#  'Day 18': 1080,
#  'Day 19': 1145,
#  'Day 2': 120,
#  'Day 20': 1200,
#  'Day 21': 1265,
#  'Day 22': 1320,
#  'Day 23': 1385,
#  'Day 24': 1440,
#  'Day 25': 1514,
#  'Day 3': 175,
#  'Day 4': 240,
#  'Day 5': 295,
#  'Day 6': 360,
#  'Day 7': 415,
#  'Day 8': 480,
#  'Day 9': 535}

# %%
odometer = pd.Series(odometer)
odometer
# Out:
# Day 1       55
# Day 2      120
# Day 3      175
# Day 4      240
# Day 5      295
# Day 6      360
# Day 7      415
# Day 8      480
# Day 9      535
# Day 10     600
# Day 11     655
# Day 12     720
# Day 13     775
# Day 14     840
# Day 15     905
# Day 16     960
# Day 17    1025
# Day 18    1080
# Day 19    1145
# Day 20    1200
# Day 21    1265
# Day 22    1320
# Day 23    1385
# Day 24    1440
# Day 25    1514
# dtype: int64

# %%
for i in range(len(odometer) - 1):
    if i == 0:
        print(f"I rode {odometer[i]} miles on day {i + 1}.")
    print(f"I rode {odometer[i + 1] - odometer[i]} miles on day {i + 2}.")
# Out:
# I rode 55 miles on day 1.
# I rode 65 miles on day 2.
# I rode 55 miles on day 3.
# I rode 65 miles on day 4.
# I rode 55 miles on day 5.
# I rode 65 miles on day 6.
# I rode 55 miles on day 7.
# I rode 65 miles on day 8.
# I rode 55 miles on day 9.
# I rode 65 miles on day 10.
# I rode 55 miles on day 11.
# I rode 65 miles on day 12.
# I rode 55 miles on day 13.
# I rode 65 miles on day 14.
# I rode 65 miles on day 15.
# I rode 55 miles on day 16.
# I rode 65 miles on day 17.
# I rode 55 miles on day 18.
# I rode 65 miles on day 19.
# I rode 55 miles on day 20.
# I rode 65 miles on day 21.
# I rode 55 miles on day 22.
# I rode 65 miles on day 23.
# I rode 55 miles on day 24.
# I rode 74 miles on day 25.
